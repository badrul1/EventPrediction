# %% [markdown]
# <h1 align="center" style="background-color:#616161;color:white">Raw Data Viewer</h1>
#
# Report for viewing very basic information about the raw data prior to processing

# %%
import os
import sys
import pandas as pd
import csv
import json

## Parameters you can change

# Abs path to settings file
root = "C:/DS/Github/MusicRecommendation"  # BA, Windows

# Select the dataset to view
datasetToUse ="inputfile_verysml" # inputfile , inputfile_sml , or inputfile_verysml


## Finish setting up
os.chdir(root)
## Add the prelim module
fPath = root + "/1_codebase"
if fPath not in sys.path: sys.path.append(fPath)
from codebase import *

# %% [markdown]
# <a id='Load Data'></a>
# <h3 style="background-color:#616161;color:white">Load Data</h3>

# %%
settingsDict =  loadSettings()
fPath = root + settingsDict[datasetToUse]

colHeadings=['UserID','Timestamp','ArtistID','ArtistName','TrackID','TrackName']
dataFormat={'UserID': str, 'Timestamp': str, 'ArtistID' :str, 'ArtistName': str, 'TrackID': str, 'TrackName': str}

parse_dates = ['Timestamp']

if dataFormat=="": 
    inpData = pd.read_csv(fPath, sep='\t', error_bad_lines= False,quoting=csv.QUOTE_NONE, header=None,names=colHeadings)
else:
    inpData = pd.read_csv(fPath, sep='\t', error_bad_lines= False,quoting=csv.QUOTE_NONE, header=None,names=colHeadings, dtype=dataFormat,parse_dates=parse_dates)

# %% [markdown]
# <a id='First 5 rows'></a>
# <h3 style="background-color:#616161;color:white">First N rows</h3>

# %%
n = 22

# %%
subset =inpData[0:n]
subset
# Out:
#          UserID           Timestamp                              ArtistID  \
# 0   user_000001 2009-05-04 23:08:57  f1b1cf71-bd35-4e99-8624-24a6e15f133a
# 1   user_000001 2009-05-03 15:48:25  ba2f4f3b-0293-4bc8-bb94-2f73b5207343
# 2   user_000001 2009-05-03 14:07:40  ce559a88-58ba-4d8a-8456-9177412d609c
# 3   user_000001 2009-05-03 14:01:15  ce559a88-58ba-4d8a-8456-9177412d609c
# 4   user_000001 2009-05-02 14:19:06  6685bdd9-37f3-4323-8f7c-0e7bb9103e6d
# 5   user_000001 2009-05-02 14:13:56  1e48cdae-b68d-4cd0-bfba-a78ad30d2e9f
# 6   user_000001 2009-05-02 14:10:09  1e48cdae-b68d-4cd0-bfba-a78ad30d2e9f
# 7   user_000001 2009-05-02 14:06:16  1e48cdae-b68d-4cd0-bfba-a78ad30d2e9f
# 8   user_000001 2009-05-02 14:01:02  1e48cdae-b68d-4cd0-bfba-a78ad30d2e9f
# 9   user_000002 2009-05-02 13:55:32  1e48cdae-b68d-4cd0-bfba-a78ad30d2e9f
# 10  user_000002 2009-06-02 13:55:32  1e48cdae-b68d-4cd0-bfba-a78ad30d2e9f
# 11  user_000002 2009-05-02 13:51:45  1e48cdae-b68d-4cd0-bfba-a78ad30d2e9f
# 12  user_000002 2009-05-02 13:46:05  1e48cdae-b68d-4cd0-bfba-a78ad30d2e9f
# 13  user_000002 2009-05-02 13:40:51  1e48cdae-b68d-4cd0-bfba-a78ad30d2e9f
# 14  user_000002 2009-06-02 13:40:51  1e48cdae-b68d-4cd0-bfba-a78ad30d2e9f
# 15  user_000002 2009-05-02 13:31:34  1e48cdae-b68d-4cd0-bfba-a78ad30d2e9f
# 16  user_000002 2009-05-02 13:25:55  1e48cdae-b68d-4cd0-bfba-a78ad30d2e9f
# 17  user_000002 2009-05-04 13:54:10  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 18  user_000002 2009-05-04 13:52:04  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 19  user_000003 2009-05-02 13:35:21  1e48cdae-b68d-4cd0-bfba-a78ad30d2e9f
# 20  user_000003 2009-05-04 13:42:52  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 21  user_000003 2009-05-04 13:42:11  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
#
#     ArtistName                               TrackID  \
# 0    Deep Dish                                   NaN
# 1   Underworld  dc394163-2b78-4b56-94e4-658597a29ef8
# 2    Masomenos                                   NaN
# 3    Masomenos                                   NaN
# 4        Gelka  fc89d5bf-a04c-41c9-836d-924e64302076
# 5     Marc Mac                                   NaN
# 6     Marc Mac                                   NaN
# 7     Marc Mac                                   NaN
# 8     Marc Mac                                   NaN
# 9     Marc Mac                                   NaN
# 10    Marc Mac                                   NaN
# 11    Marc Mac                                   NaN
# 12    Marc Mac                                   NaN
# 13    Marc Mac                                   NaN
# 14    Marc Mac                                   NaN
# 15    Marc Mac                                   NaN
# 16    Marc Mac                                   NaN
# 17        坂本龍一                                   NaN
# 18        坂本龍一                                   NaN
# 19    Marc Mac                                   NaN
# 20        坂本龍一                                   NaN
# 21        坂本龍一                                   NaN
#
#                                      TrackName
# 0   Fuck Me Im Famous (Pacha Ibiza)-09-28-2007
# 1                 Boy, Boy, Boy (Switch Remix)
# 2                                        Seven
# 3                                          Six
# 4                                   Rasta Baby
# 5                                     Backspin
# 6                                  Jazz Flares
# 7                                       Freeze
# 8                                     Footwork
# 9                                     Backspin
# 10                                    Backspin
# 11                                 Jazz Flares
# 12                                      Freeze
# 13                                    Footwork
# 14                                    Footwork
# 15                                 Jazz Flares
# 16                                      Freeze
# 17           Composition 0919 (Live_2009_4_15)
# 18                        Mc2 (Live_2009_4_15)
# 19                                    Backspin
# 20                     Hibari (Live_2009_4_15)
# 21                        Mc1 (Live_2009_4_15)

# %% [markdown]
# <a id='Describe the Data'></a>
# <h3 style="background-color:#616161;color:white">Describe the Data</h3>

# %%
inpData.describe()
# Out:
#              UserID            Timestamp  \
# count            22                   22
# unique            3                   22
# top     user_000002  2009-05-02 13:40:51
# freq             10                    1
# first           NaN  2009-05-02 13:25:55
# last            NaN  2009-06-02 13:55:32
#
#                                     ArtistID ArtistName  \
# count                                     22         22
# unique                                     6          6
# top     1e48cdae-b68d-4cd0-bfba-a78ad30d2e9f   Marc Mac
# freq                                      13         13
# first                                    NaN        NaN
# last                                     NaN        NaN
#
#                                      TrackID TrackName
# count                                      2        22
# unique                                     2        13
# top     fc89d5bf-a04c-41c9-836d-924e64302076  Backspin
# freq                                       1         4
# first                                    NaN       NaN
# last                                     NaN       NaN
