# %% [markdown]
# <h1 align="center" style="background-color:#616161;color:white">Next play prediction using Bayesian Inference</h1>

# %% [markdown]
# Here we shall apply Bayesian Inference, and specifically a Beta conjugate prior, to determine the liklihood of a user listening
# to music in a given time slot.
#
# <h4>Methodology</h4>
# * $\theta$ is the probability of someone listening to music in a given Timeslot. This is what we wish to determine.
# * Our prior beliefs will be based on analyzing the entire population, and our posterior belief will be to take into account a users personal play history up to the cut-off point for the training data
#
# $p(\theta_{jt} | Y_{jt}) = Beta(\alpha_{jt} + Y_{jt}, \beta_{jt} + N_{jt}-Y_{jt})$
# for user j, at time slot $t$
#
# * Note: How we determine the prior probability is based on analyzing how many times users played music in that time slot out of the total number of chances they had to listen to music in that time slot. This latter amount has to be estimated from the data in a somewhat crude manner (count up the total number of weeks they listened to music in ANY timeslot ).

# %% [markdown]
# <h3 style="background-color:#616161;color:white">0. Setup</h3>

# %% [markdown]
# <div style="background-color:white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Input Parameters</div>

# %%
# Train / Test split
newUsers = 10   # Num of randomly selected users to separate out of eval 2

# Root path
#root = "C:/DS/Github/MusicRecommendation"  # BA, Windows
root = "/home/badrul/git/EventPrediction" # BA, Linux

# %% [markdown]
# <div style="background-color:white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Import Libraries</div>

# %%
# Core
import numpy as np
import pandas as pd
from IPython.core.debugger import Tracer    # Used for debugging
import logging

# File and database management
import csv
import os
import sys
import json
import sqlite3
from pathlib import Path

# Date/Time
import datetime
import time
from datetime import timedelta
# Recommend switching to: http://arrow.readthedocs.io/en/latest/

# Visualization
from ggplot import *                        # Preferred
import matplotlib.pyplot as plt             # Quick
# %matplotlib inline

# Data science (comment out if not needed)
#from sklearn.manifold import TSNE
from sklearn.metrics import roc_curve, auc

# Misc
import random

#-------------- Custom Libs -----------------#
os.chdir(root)

# Import the codebase module
fPath = root + "/1_codemodule"
if fPath not in sys.path: sys.path.append(fPath)

# Custom Libs
import coreCode as cc
import lastfmCode as fm

# %% [markdown]
# <div style="background-color:#white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Declare Functions</div>

# %%
# Function definition

def estBetaParams(mu, var):
    a = ((1 - mu) / var - 1 / mu) * mu**2
    b = a * (1 / mu - 1)
    return (a,b)

def getNextPlayProb_Beta(df,Timeslot):
    # Calculate posteriors: a=a+y and b=b+n-y
    playCount = df[df.Timeslot == Timeslot]['PlayCount'].sum()
    # Count num of weeks up to this point
    totalWks = len(df.PlayDate.dt.week.unique())
    a = priorDf.loc[Timeslot]['a'] + playCount
    b = priorDf.loc[Timeslot]['b'] + totalWks-playCount
    #Tracer()()
    mu = a/(a+b)
    #print(playCount,totalWks,a,b,mu)
    return mu

def toTimeSlot(dt, periodInterval):
    return str(int(dt.strftime('%w'))+1) +dt.strftime('-%H-') + str(int((int(dt.strftime('%M'))/periodInterval+1)))

def CalcProb(df):
    df.reset_index(inplace=True, drop=True)  # Important that this line is run every time the rest of it is run
    
    for i in range (0,df.shape[0]):       # let i go through 1 to length
        timeslot = df.iloc[i]['Timeslot']  
        userID = df.iloc[i]['UserID']
        df2=df.iloc[0:i][df.UserID == userID]          # Extract just rows up to point i for this user
        res = getNextPlayProb_Beta(df2,timeslot)   # Filter for the specific user and pass to function
        df.loc[(i),'EstProb'] = res
    return df

def evaluateThreshold(df, thresholds):
    l=len(thresholds)
    userID = str(df.iloc[0].UserID)
    res=np.matrix( [[userID]*l, thresholds, [0]*l] ).reshape(3,l).T
    i=0
    
    for t in thresholds:
        correctPos = df[(df.EstProb >= t) & (df.PlayCount>0)]['PlayCount'].count()
        correctNeg = df[(df.EstProb < t) & (df.PlayCount==0)]['PlayCount'].count()
        totalRows = len(df)
        percent = (correctPos+correctNeg)/totalRows
        #print("Threshold: {}. Total correct(Play): {} Total correct(NoPlay): {} Total Rows:{}  %: {}".format(t,correctPos,correctNeg,totalRows,percent))
        res[i,2] = percent
        i+=1
    res=pd.DataFrame(res,columns=['UserID','Threshold','Perc. Correct'])
    res[['Threshold','Perc. Correct']] = res[['Threshold','Perc. Correct']].apply(pd.to_numeric)
    return res

def getTrainAndTestData():
    con = sqlite3.connect(dbPath)
    c = con.cursor()

    # Get list of UserIDs 
    users = pd.read_sql_query("Select UserID from tblUsers Where tblUsers.TestUser = 0",con)

    fieldList="t, UserID, HrsFrom6pm, isSun,isMon,isTue,isWed,isThu,isFri,isSat,t1,t2,t3,t4,t5,t10,t12hrs,t24hrs,t1wk,t2wks,t3wks,t4wks"
    trainDf=pd.DataFrame(columns=[fieldList])  # Create an emmpty df
    testDf=pd.DataFrame(columns=[fieldList])  # Create an emmpty df
    periodsInAMonth=int(60/periodGranularity)*24*7*4

    totalRows=0
    
    for user in users.itertuples():
        # Get training dataset
        SqlStr="""
        SELECT UserID, PlayDate, Timeslot, sum(PlayedMusic) as PlayCount from tblMainAgg 
        where UserID = {} group by UserID, PlayDate, Timeslot """.format(user.userID)
    
        df = pd.read_sql_query(SqlStr, con)
        
        if (len(df)> periodsInAMonth*3):
            totalRows += len(df)

            # Cut-off 1
            k = random.randint(periodsInAMonth, len(df))  # Pick a random data point after  the first 100 plays
            #Tracer()()  -- for debugging purposes
            testDf = testDf.append(df.iloc[k:k+periodsInAMonth])[df.columns.tolist()]

            tmp = df.drop(df.index[k:k+periodsInAMonth])

            # Cut-off 2
            k = random.randint(periodsInAMonth, len(tmp))
            testDf = testDf.append(tmp.iloc[k:k+periodsInAMonth])[df.columns.tolist()]
            trainDf = trainDf.append(tmp.drop(tmp.index[k:k+periodsInAMonth]))[df.columns.tolist()]
        else:
            print('Skipping user {} as not enough periods ({})'.format(user.userID,len(df)))
            
    if len(trainDf)+len(testDf) == totalRows:
        print('Ok')
    else:
        print("Incorrect. Total Rows = {}. TestDf+TrainDf rows = {}+{}={}".format(totalRows,len(testDf),len(trainDf),len(testDf)+len(trainDf)))
    
    # Remove playdate from train data and aggregate up
    trainDf.drop('PlayDate', axis=1, inplace=True)
    trainDf["UserID"] =  trainDf["UserID"].astype(int)
    trainDf=trainDf.groupby(['UserID', 'Timeslot'],as_index=False).sum()
    
    testDf["PlayDate"] = pd.to_datetime(testDf["PlayDate"])
    testDf["UserID"] =  testDf["UserID"].astype(int)
    testDf.sort_values(['UserID','PlayDate'], inplace=True)
    return trainDf, testDf

def getHiddenTestUsers(firstNPerc=1.0):
    con = sqlite3.connect(dbPath)
    c = con.cursor()

    # Get list of UserIDs 
    users = pd.read_sql_query("Select UserID from tblUsers Where tblUsers.TestUser = 1",con)

    fieldList="t, UserID, HrsFrom6pm, isSun,isMon,isTue,isWed,isThu,isFri,isSat,t1,t2,t3,t4,t5,t10,t12hrs,t24hrs,t1wk,t2wks,t3wks,t4wks"
    testDf=pd.DataFrame(columns=[fieldList])  # Create an emmpty df
    periodsInAMonth=int(60/periodGranularity)*24*7*4

    totalRows=0
    
    for user in users.itertuples():
        # Get training dataset
        SqlStr="""
        SELECT UserID, PlayDate, Timeslot, sum(PlayedMusic) as PlayCount from tblMainAgg 
        where UserID = {} group by UserID, PlayDate, Timeslot Order By PlayDate""".format(user.userID)
    
        df = pd.read_sql_query(SqlStr, con)
        df["PlayDate"] = pd.to_datetime(df["PlayDate"])
        df.sort_values(['PlayDate'])
        totalRows += len(df)
        # Caluclate period cutt-off
        cutoff = int(len(df)*firstNPerc)
        testDf = testDf.append(df.iloc[0:cutoff])[df.columns.tolist()]
 
    testDf["PlayDate"] = pd.to_datetime(testDf["PlayDate"])
    testDf["UserID"] =  testDf["UserID"].astype(int)
    testDf.sort_values(['UserID','PlayDate'], inplace=True)
    return testDf

# %% [markdown]
# <div style="background-color:#white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Load settings</div>

# %%
settingsDict =  cc.loadSettings()
dbPath = root + settingsDict['mainDbPath']
fmSimilarDbPath = root + settingsDict['fmSimilarDbPath']
fmTagsDbPath = root + settingsDict['fmTagsDbPath']
trackMetaDbPath = root + settingsDict['trackmetadata']
periodGranularity = int(settingsDict['periodGranularity'])

# %% [markdown]
# <div style="background-color:#white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Other setup</div>
# None

# %% [markdown]
# <h3 style="background-color:#616161;color:white">1. Get train & test data</h3>

# %%
trainDf,testDf = getTrainAndTestData()

con = sqlite3.connect(dbPath)
# Also fetch the total number of weeks each user has played music
sqlStr = "Select userID, count(DISTINCT (strftime('%W',PlayedTimestamp)||strftime('%Y',PlayedTimestamp))) as TotalWks from tblMain group by userID"
wks = pd.read_sql_query(sqlStr, con)
wks.set_index('UserID',inplace=True)
con.close()
# Out:
# Skipping user 42 as not enough periods (0)
# Skipping user 43 as not enough periods (0)
# Skipping user 44 as not enough periods (0)
# Skipping user 45 as not enough periods (0)
# Skipping user 46 as not enough periods (0)
# Skipping user 47 as not enough periods (0)
# Skipping user 48 as not enough periods (0)
# Skipping user 49 as not enough periods (0)
# Skipping user 50 as not enough periods (0)
# Skipping user 51 as not enough periods (0)
# Skipping user 52 as not enough periods (0)
# Skipping user 53 as not enough periods (0)
# Skipping user 54 as not enough periods (0)
# Skipping user 55 as not enough periods (0)
# Skipping user 56 as not enough periods (0)
# Skipping user 57 as not enough periods (0)
# Skipping user 58 as not enough periods (0)
# Skipping user 59 as not enough periods (0)
# Skipping user 60 as not enough periods (0)
# Skipping user 61 as not enough periods (0)
# Skipping user 62 as not enough periods (0)
# Skipping user 63 as not enough periods (0)
# Skipping user 64 as not enough periods (0)
# Skipping user 65 as not enough periods (0)
# Skipping user 66 as not enough periods (0)
# Skipping user 67 as not enough periods (0)
# Skipping user 69 as not enough periods (0)
# Skipping user 70 as not enough periods (0)
# Skipping user 71 as not enough periods (0)
# Skipping user 72 as not enough periods (0)
# Skipping user 73 as not enough periods (0)
# Skipping user 74 as not enough periods (0)
# Skipping user 75 as not enough periods (0)
# Skipping user 76 as not enough periods (0)
# Skipping user 77 as not enough periods (0)
# Skipping user 78 as not enough periods (0)
# Skipping user 79 as not enough periods (0)
# Skipping user 80 as not enough periods (0)
# Skipping user 81 as not enough periods (0)
# Skipping user 82 as not enough periods (0)
# Skipping user 83 as not enough periods (0)
# Skipping user 84 as not enough periods (0)
# Skipping user 85 as not enough periods (0)
# Skipping user 86 as not enough periods (0)
# Skipping user 88 as not enough periods (0)
# Skipping user 89 as not enough periods (0)
# Skipping user 90 as not enough periods (0)
# Skipping user 91 as not enough periods (0)
# Skipping user 92 as not enough periods (0)
# Skipping user 93 as not enough periods (0)
# Skipping user 94 as not enough periods (0)
# Skipping user 95 as not enough periods (0)
# Skipping user 96 as not enough periods (0)
# Skipping user 97 as not enough periods (0)
# Skipping user 98 as not enough periods (0)
# Skipping user 99 as not enough periods (0)
# Skipping user 100 as not enough periods (0)
# Skipping user 101 as not enough periods (0)
# Skipping user 102 as not enough periods (0)
# Skipping user 103 as not enough periods (0)
# Skipping user 104 as not enough periods (0)
# Skipping user 105 as not enough periods (0)
# Skipping user 106 as not enough periods (0)
# Skipping user 107 as not enough periods (0)
# Skipping user 108 as not enough periods (0)
# Skipping user 109 as not enough periods (0)
# Skipping user 110 as not enough periods (0)
# Skipping user 111 as not enough periods (0)
# Skipping user 112 as not enough periods (0)
# Skipping user 113 as not enough periods (0)
# Skipping user 114 as not enough periods (0)
# Skipping user 115 as not enough periods (0)
# Skipping user 116 as not enough periods (0)
# Skipping user 117 as not enough periods (0)
# Skipping user 118 as not enough periods (0)
# Skipping user 119 as not enough periods (0)
# Skipping user 120 as not enough periods (0)
# Skipping user 121 as not enough periods (0)
# Skipping user 122 as not enough periods (0)
# Skipping user 123 as not enough periods (0)
# Skipping user 124 as not enough periods (0)
# Skipping user 125 as not enough periods (0)
# Skipping user 126 as not enough periods (0)
# Skipping user 127 as not enough periods (0)
# Skipping user 128 as not enough periods (0)
# Skipping user 129 as not enough periods (0)
# Skipping user 130 as not enough periods (0)
# Skipping user 131 as not enough periods (0)
# Skipping user 132 as not enough periods (0)
# Skipping user 133 as not enough periods (0)
# Skipping user 134 as not enough periods (0)
# Skipping user 135 as not enough periods (0)
# Skipping user 136 as not enough periods (0)
# Skipping user 137 as not enough periods (0)
# Skipping user 138 as not enough periods (0)
# Skipping user 139 as not enough periods (0)
# Skipping user 140 as not enough periods (0)
# Skipping user 141 as not enough periods (0)
# Skipping user 142 as not enough periods (0)
# Skipping user 143 as not enough periods (0)
# Skipping user 144 as not enough periods (0)
# Skipping user 145 as not enough periods (0)
# Skipping user 146 as not enough periods (0)
# Skipping user 147 as not enough periods (0)
# Skipping user 148 as not enough periods (0)
# Skipping user 149 as not enough periods (0)
# Skipping user 150 as not enough periods (0)
# Skipping user 151 as not enough periods (0)
# Skipping user 152 as not enough periods (0)
# Skipping user 153 as not enough periods (0)
# Skipping user 154 as not enough periods (0)
# Skipping user 155 as not enough periods (0)
# Skipping user 156 as not enough periods (0)
# Skipping user 157 as not enough periods (0)
# Skipping user 158 as not enough periods (0)
# Skipping user 159 as not enough periods (0)
# Skipping user 160 as not enough periods (0)
# Skipping user 161 as not enough periods (0)
# Skipping user 162 as not enough periods (0)
# Skipping user 163 as not enough periods (0)
# Skipping user 164 as not enough periods (0)
# Skipping user 165 as not enough periods (0)
# Skipping user 166 as not enough periods (0)
# Skipping user 167 as not enough periods (0)
# Skipping user 168 as not enough periods (0)
# Skipping user 169 as not enough periods (0)
# Skipping user 170 as not enough periods (0)
# Skipping user 171 as not enough periods (0)
# Skipping user 172 as not enough periods (0)
# Skipping user 173 as not enough periods (0)
# Skipping user 174 as not enough periods (0)
# Skipping user 175 as not enough periods (0)
# Skipping user 176 as not enough periods (0)
# Skipping user 177 as not enough periods (0)
# Skipping user 178 as not enough periods (0)
# Skipping user 179 as not enough periods (0)
# Skipping user 180 as not enough periods (0)
# Skipping user 181 as not enough periods (0)
# Skipping user 182 as not enough periods (0)
# Skipping user 183 as not enough periods (0)
# Skipping user 184 as not enough periods (0)
# Skipping user 185 as not enough periods (0)
# Skipping user 186 as not enough periods (0)
# Skipping user 187 as not enough periods (0)
# Skipping user 188 as not enough periods (0)
# Skipping user 189 as not enough periods (0)
# Skipping user 190 as not enough periods (0)
# Skipping user 191 as not enough periods (0)
# Skipping user 192 as not enough periods (0)
# Skipping user 193 as not enough periods (0)
# Skipping user 194 as not enough periods (0)
# Skipping user 195 as not enough periods (0)
# Skipping user 196 as not enough periods (0)
# Skipping user 197 as not enough periods (0)
# Skipping user 198 as not enough periods (0)
# Skipping user 199 as not enough periods (0)
# Skipping user 200 as not enough periods (0)
# Skipping user 201 as not enough periods (0)
# Skipping user 202 as not enough periods (0)
# Skipping user 203 as not enough periods (0)
# Skipping user 204 as not enough periods (0)
# Skipping user 205 as not enough periods (0)
# Skipping user 206 as not enough periods (0)
# Skipping user 207 as not enough periods (0)
# Skipping user 208 as not enough periods (0)
# Skipping user 209 as not enough periods (0)
# Skipping user 210 as not enough periods (0)
# Skipping user 211 as not enough periods (0)
# Skipping user 212 as not enough periods (0)
# Skipping user 213 as not enough periods (0)
# Skipping user 214 as not enough periods (0)
# Skipping user 215 as not enough periods (0)
# Skipping user 216 as not enough periods (0)
# Skipping user 217 as not enough periods (0)
# Skipping user 218 as not enough periods (0)
# Skipping user 219 as not enough periods (0)
# Skipping user 220 as not enough periods (0)
# Skipping user 221 as not enough periods (0)
# Skipping user 222 as not enough periods (0)
# Skipping user 223 as not enough periods (0)
# Skipping user 224 as not enough periods (0)
# Skipping user 225 as not enough periods (0)
# Skipping user 226 as not enough periods (0)
# Skipping user 227 as not enough periods (0)
# Skipping user 228 as not enough periods (0)
# Skipping user 229 as not enough periods (0)
# Skipping user 230 as not enough periods (0)
# Skipping user 231 as not enough periods (0)
# Skipping user 232 as not enough periods (0)
# Skipping user 233 as not enough periods (0)
# Skipping user 234 as not enough periods (0)
# Skipping user 235 as not enough periods (0)
# Skipping user 236 as not enough periods (0)
# Skipping user 237 as not enough periods (0)
# Skipping user 238 as not enough periods (0)
# Skipping user 239 as not enough periods (0)
# Skipping user 240 as not enough periods (0)
# Skipping user 241 as not enough periods (0)
# Skipping user 242 as not enough periods (0)
# Skipping user 243 as not enough periods (0)
# Skipping user 244 as not enough periods (0)
# Skipping user 245 as not enough periods (0)
# Skipping user 246 as not enough periods (0)
# Skipping user 247 as not enough periods (0)
# Skipping user 248 as not enough periods (0)
# Skipping user 249 as not enough periods (0)
# Skipping user 250 as not enough periods (0)
# Skipping user 251 as not enough periods (0)
# Skipping user 252 as not enough periods (0)
# Skipping user 253 as not enough periods (0)
# Skipping user 254 as not enough periods (0)
# Skipping user 255 as not enough periods (0)
# Skipping user 256 as not enough periods (0)
# Skipping user 257 as not enough periods (0)
# Skipping user 258 as not enough periods (0)
# Skipping user 259 as not enough periods (0)
# Skipping user 260 as not enough periods (0)
# Skipping user 261 as not enough periods (0)
# Skipping user 262 as not enough periods (0)
# Skipping user 263 as not enough periods (0)
# Skipping user 264 as not enough periods (0)
# Skipping user 265 as not enough periods (0)
# Skipping user 266 as not enough periods (0)
# Skipping user 267 as not enough periods (0)
# Skipping user 268 as not enough periods (0)
# Skipping user 269 as not enough periods (0)
# Skipping user 270 as not enough periods (0)
# Skipping user 271 as not enough periods (0)
# Skipping user 272 as not enough periods (0)
# Skipping user 273 as not enough periods (0)
# Skipping user 274 as not enough periods (0)
# Skipping user 275 as not enough periods (0)
# Skipping user 276 as not enough periods (0)
# Skipping user 277 as not enough periods (0)
# Skipping user 278 as not enough periods (0)
# Skipping user 279 as not enough periods (0)
# Skipping user 280 as not enough periods (0)
# Skipping user 281 as not enough periods (0)
# Skipping user 282 as not enough periods (0)
# Skipping user 284 as not enough periods (0)
# Skipping user 285 as not enough periods (0)
# Skipping user 286 as not enough periods (0)
# Skipping user 288 as not enough periods (0)
# Skipping user 289 as not enough periods (0)
# Skipping user 290 as not enough periods (0)
# Skipping user 291 as not enough periods (0)
# Skipping user 292 as not enough periods (0)
# Skipping user 293 as not enough periods (0)
# Skipping user 294 as not enough periods (0)
# Skipping user 295 as not enough periods (0)
# Skipping user 296 as not enough periods (0)
# Skipping user 297 as not enough periods (0)
# Skipping user 298 as not enough periods (0)
# Skipping user 299 as not enough periods (0)
# Skipping user 300 as not enough periods (0)
# Skipping user 301 as not enough periods (0)
# Skipping user 302 as not enough periods (0)
# Skipping user 303 as not enough periods (0)
# Skipping user 304 as not enough periods (0)
# Skipping user 305 as not enough periods (0)
# Skipping user 306 as not enough periods (0)
# Skipping user 307 as not enough periods (0)
# Skipping user 308 as not enough periods (0)
# Skipping user 309 as not enough periods (0)
# Skipping user 310 as not enough periods (0)
# Skipping user 311 as not enough periods (0)
# Skipping user 312 as not enough periods (0)
# Skipping user 313 as not enough periods (0)
# Skipping user 314 as not enough periods (0)
# Skipping user 315 as not enough periods (0)
# Skipping user 316 as not enough periods (0)
# Skipping user 317 as not enough periods (0)
# Skipping user 318 as not enough periods (0)
# Skipping user 319 as not enough periods (0)
# Skipping user 320 as not enough periods (0)
# Skipping user 321 as not enough periods (0)
# Skipping user 322 as not enough periods (0)
# Skipping user 323 as not enough periods (0)
# Skipping user 324 as not enough periods (0)
# Skipping user 325 as not enough periods (0)
# Skipping user 326 as not enough periods (0)
# Skipping user 327 as not enough periods (0)
# Skipping user 328 as not enough periods (0)
# Skipping user 329 as not enough periods (0)
# Skipping user 330 as not enough periods (0)
# Skipping user 331 as not enough periods (0)
# Skipping user 332 as not enough periods (0)
# Skipping user 333 as not enough periods (0)
# Skipping user 334 as not enough periods (0)
# Skipping user 335 as not enough periods (0)
# Skipping user 336 as not enough periods (0)
# Skipping user 337 as not enough periods (0)
# Skipping user 338 as not enough periods (0)
# Skipping user 339 as not enough periods (0)
# Skipping user 340 as not enough periods (0)
# Skipping user 341 as not enough periods (0)
# Skipping user 342 as not enough periods (0)
# Skipping user 343 as not enough periods (0)
# Skipping user 344 as not enough periods (0)
# Skipping user 345 as not enough periods (0)
# Skipping user 346 as not enough periods (0)
# Skipping user 347 as not enough periods (0)
# Skipping user 348 as not enough periods (0)
# Skipping user 349 as not enough periods (0)
# Skipping user 350 as not enough periods (0)
# Skipping user 351 as not enough periods (0)
# Skipping user 352 as not enough periods (0)
# Skipping user 353 as not enough periods (0)
# Skipping user 354 as not enough periods (0)
# Skipping user 355 as not enough periods (0)
# Skipping user 356 as not enough periods (0)
# Skipping user 357 as not enough periods (0)
# Skipping user 358 as not enough periods (0)
# Skipping user 359 as not enough periods (0)
# Skipping user 360 as not enough periods (0)
# Skipping user 361 as not enough periods (0)
# Skipping user 362 as not enough periods (0)
# Skipping user 363 as not enough periods (0)
# Skipping user 364 as not enough periods (0)
# Skipping user 366 as not enough periods (0)
# Skipping user 367 as not enough periods (0)
# Skipping user 368 as not enough periods (0)
# Skipping user 369 as not enough periods (0)
# Skipping user 370 as not enough periods (0)
# Skipping user 371 as not enough periods (0)
# Skipping user 372 as not enough periods (0)
# Skipping user 373 as not enough periods (0)
# Skipping user 374 as not enough periods (0)
# Skipping user 375 as not enough periods (0)
# Skipping user 376 as not enough periods (0)
# Skipping user 377 as not enough periods (0)
# Skipping user 378 as not enough periods (0)
# Skipping user 379 as not enough periods (0)
# Skipping user 380 as not enough periods (0)
# Skipping user 381 as not enough periods (0)
# Skipping user 382 as not enough periods (0)
# Skipping user 383 as not enough periods (0)
# Skipping user 384 as not enough periods (0)
# Ok

# %% [markdown]
# <div style="background-color:white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Preview Results</div>

# %%
trainDf.head()
# Out:
#    UserID Timeslot  PlayCount
# 0       2   1-00-1       19.0
# 1       2   1-00-2       15.0
# 2       2   1-01-1       12.0
# 3       2   1-01-2       12.0
# 4       2   1-02-1       11.0

# %%
testDf.head()
# Out:
#        UserID   PlayDate Timeslot  PlayCount
# 37900       2 2008-04-24   5-08-1        0.0
# 37901       2 2008-04-24   5-08-2        0.0
# 37902       2 2008-04-24   5-09-1        0.0
# 37903       2 2008-04-24   5-09-2        0.0
# 37904       2 2008-04-24   5-10-1        0.0

# %%
wks.head()
# Out:
#         TotalWks
# UserID
# 1            107
# 2            157
# 3            140
# 4             95
# 5            125

# %% [markdown]
# Note we are now capturing all song plays, and not just the start of a listening session so the pattern isn't as obvious as before

# %%
trainDf[trainDf.PlayCount >0].plot(x='Timeslot', y='PlayCount',figsize=[15,3],title='Total play count by HH Timeslot')

# %% [markdown]
# <h3 style="background-color:#616161;color:white">3. Construct prior probability from train data</h3>

# %% [markdown]
# Here we shall determine the alpa and beta parameters for a Beta distribution by calculating the probability of play in each timeslot, and then taking the mean and variance of this.

# %%
try:
    del trainDf['TotalWks']    # Delete col if it already exists
except KeyError:
    pass

# Calculate probability
trainDf=trainDf.set_index('UserID').join(wks)                      # Bring in total weeks from wks table
trainDf['Prob'] = trainDf['PlayCount'] / trainDf['TotalWks']      # Prob = num of plays in this period / total num of weeks
trainDf.reset_index(inplace=True)

# Calculate the Priors from trainDf. Note: We are taking the mean of the user means here
priorDf= trainDf.groupby('Timeslot')['Prob'].mean().to_frame('mean')  # Calculate the mean of prob for each period
priorDf['var'] = trainDf.groupby('Timeslot')['Prob'].var()           # Calculate the variance of prob for each period
a,b=estBetaParams(priorDf['mean'],priorDf['var'])                # Derive alpha & beta for the Beta dist
priorDf['a']= a                                                 # Store a and b back into priorDf
priorDf['b']= b

# %% [markdown]
# <div style="background-color:white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Preview Results</div>

# %%
trainDf.head()
# Out:
#    UserID Timeslot  PlayCount  TotalWks      Prob
# 0       2   1-00-1       19.0       157  0.121019
# 1       2   1-00-2       15.0       157  0.095541
# 2       2   1-01-1       12.0       157  0.076433
# 3       2   1-01-2       12.0       157  0.076433
# 4       2   1-02-1       11.0       157  0.070064

# %%
priorDf.head()
# Out:
#               mean       var         a         b
# Timeslot
# 1-00-1    0.129698  0.015022  0.844861  5.669220
# 1-00-2    0.121089  0.014370  0.775727  5.630537
# 1-01-1    0.119218  0.016120  0.657381  4.856713
# 1-01-2    0.110413  0.014912  0.616877  4.970113
# 1-02-1    0.103882  0.013271  0.624827  5.389943

# %% [markdown]
# <div style="background-color:white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Additional Checks</div>

# %% [markdown]
# Let's do a few checks to make sure we've calculated the probability correctly.
#
# Check that the min/max is within 0-1 boundaries

# %%
trainDf['Prob'].describe()
# Out:
# count    11088.000000
# mean         0.117550
# std          0.108503
# min          0.000000
# 25%          0.027586
# 50%          0.089552
# 75%          0.188679
# max          0.682353
# Name: Prob, dtype: float64

# %% [markdown]
# Let's do a histogram to see what the distribution looks like

# %%
ggplot(aes(x='Prob'), data=trainDf) + \
    geom_histogram(binwidth=0.05)
# Out:
# <ggplot: (-9223363252324222853)>

# %% [markdown]
# The histogram above shows that most of the probabilities are very low which is as expected.
#
# More crucially we can plot this distribution for a specific time-period.

# %%
Timeslot='2-18-1'
ggplot(aes(x='Prob'), data=trainDf[trainDf.Timeslot==Timeslot]) + \
    geom_histogram(binwidth=0.01) + ggtitle("Day {}, Hour {}, Sub-interval {}".format(Timeslot[0],Timeslot[2:4],Timeslot[5]))
# Out:
# <ggplot: (-9223363252319128039)>

# %% [markdown]
# Hour 18 (6pm) is one of the most popular times for listening to music. We see that for some users this probability is as high as 0.9. It is the mean and variance for each of these timeslot distributions that will be used to form a set of alpha and betas for our prior beta distribution model, as shown below.

# %% [markdown]
# <div style="background-color:white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Plot of Beta distribution for specific timeslot</div>

# %%
from scipy.stats import beta


p = '2-16-1'
a = priorDf.loc[p]['a']
b = priorDf.loc[p]['b']

# Plot our prior Beta PDF
fig, ax = plt.subplots(1, 1)
x = np.linspace(beta.ppf(0.01, a, b),beta.ppf(0.99, a, b), 100)  # Generate prob distribution
ax.set_xlabel('Theta (i.e. prob of listening to music)')
ax.set_ylabel('p(Theta)')

fig.suptitle('Prior prob for day {}, hour {}, interval {}'.format(p[0],p[2:4],p[5]))
ax.plot(x, beta.pdf(x, a, b),'r-', lw=5, alpha=0.6)

# %% [markdown]
# <h3 style="background-color:#616161;color:white">4. Test Set</h3>

# %%
# Calculate each users prob
testDf=CalcProb(testDf)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# <div style="background-color:white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Preview results</div>

# %%
testDf[(testDf.Timeslot == '1-17-1')].head()
# Out:
#       UserID   PlayDate Timeslot  PlayCount   EstProb
# 162        2 2008-04-27   1-17-1        1.0  0.150552
# 498        2 2008-05-04   1-17-1        0.0  0.246488
# 834        2 2008-05-11   1-17-1        0.0  0.221475
# 1170       2 2008-05-18   1-17-1        0.0  0.201071
# 1566       2 2008-06-29   1-17-1        0.0  0.169786

# %% [markdown]
# <div style="background-color:white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Plot some of the results</div>

# %%
# Select timeslots to plot
t=['3-04-1','3-08-1','3-12-1','3-18-1','3-22-1']
users=[2,5,15,21,35,33]
df=testDf[(testDf.Timeslot.isin(t) & testDf.UserID.isin(users))]
ggplot(df, aes(x='PlayDate', y='EstProb',color='Timeslot')) + geom_line()  + scale_y_continuous(limits=(0,1)) + facet_wrap("UserID",scales="free_x") + ggtitle("Prob of listening during on Wednesdays, over time, by UserID")
# Out:
# <ggplot: (8784535450204)>

# %%
# Select timeslots to plot
t=['7-04-1','7-08-1','7-12-1','7-18-1','7-22-1']
users=[2,5,15,21,35,33]
df=testDf[(testDf.Timeslot.isin(t) & testDf.UserID.isin(users))]
ggplot(df, aes(x='PlayDate', y='EstProb',color='Timeslot')) + geom_line() + scale_y_continuous(limits=(0,1)) + facet_wrap("UserID",scales="free_x") + ggtitle("Prob of listening on Saturdays, over time, by UserID")
# Out:
# <ggplot: (8784533340978)>

# %% [markdown]
# The above charts show that the Beta model adapts to persons preference over a couple of months, provided they are regular listeners.

# %% [markdown]
# <div style="background-color:white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Decide optimal threshold</div>

# %%
res = pd.DataFrame()
for user in testDf.UserID.unique():
    tmp=evaluateThreshold(testDf[(testDf.UserID == user)],[0.03,0.05,0.1,0.2,0.3,0.5,0.6,0.7,0.8,0.99])
    res= res.append(tmp)

res.groupby(['Threshold']).mean().plot()

# %% [markdown]
# This is not a good way of analyzing threshold as the highest % is when all the non=plays are guessed correctly at the expense of the plays. Instead we use the following chart:

# %%
from sklearn import metrics
import pandas as pd
from ggplot import *

actuals=testDf['PlayCount']
preds=(testDf['EstProb'])
fpr, tpr, thresholds = metrics.roc_curve(actuals, preds)

rocRes = pd.DataFrame(dict(fpr=fpr, tpr=tpr))
ggplot(rocRes, aes(x='fpr', y='tpr')) +\
    geom_line() +\
    geom_abline(linetype='dashed')
# Out:
# <ggplot: (-9223363252319321326)>

# %% [markdown]
# 0.4 is deemed to be the optimal threshold

# %% [markdown]
# <div style="background-color:white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Evaluate accuracy</div>

# %%
print(metrics.classification_report((testDf.PlayCount.values >0)*1,(testDf.EstProb.values >= 0.4)*1))
print(metrics.confusion_matrix((testDf.PlayCount.values >0)*1,(testDf.EstProb.values >= 0.4)*1))
print("* Precision = labelled as x / how many were actually x in the ones that were labelled")
print("* Recall = labelled as x / how many were actually x in the dataset")
# Out:
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94     75907
#           1       0.45      0.00      0.00      9344
#
# avg / total       0.84      0.89      0.84     85251
#
# [[75884    23]
#  [ 9325    19]]
# * Precision = labelled as x / how many were actually x in the ones that were labelled
# * Recall = labelled as x / how many were actually x in the dataset

# %% [markdown]
# <div style="background-color:white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Assess individualized thresholds</div>

# %% [markdown]
# <div style="background-color:white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Assess unseen users</div>

# %%
testDf2 = getHiddenTestUsers(firstNPerc=0.5)  # Get the first half of everyones history
testDf2.PlayDate.min(),testDf2.PlayDate.max()
# Out:
# (Timestamp('2005-09-15 00:00:00'), Timestamp('2008-07-21 00:00:00'))

# %%
# Evaluate - remember the test periods here are much more than what we had in the random period sampling from train users
#testDf2=CalcProb(testDf2)
print(metrics.classification_report((testDf2.PlayCount.values >0)*1,(testDf2.EstProb.values >= 0.4)*1))
print(metrics.confusion_matrix((testDf2.PlayCount.values >0)*1,(testDf2.EstProb.values >= 0.4)*1))
print("* Precision = labelled as x / how many were actually x in the ones that were labelled")
print("* Recall = labelled as x / how many were actually x in the dataset")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-475266a6dfbc> in <module>()
#       1 # Evaluate - remember the test periods here are much more than what we had in the random period sampling from train users
#       2 #testDf2=CalcProb(testDf2)
# ----> 3 print(metrics.classification_report((testDf2.PlayCount.values >0)*1,(testDf2.EstProb.values >= 0.4)*1))
#       4 print(metrics.confusion_matrix((testDf2.PlayCount.values >0)*1,(testDf2.EstProb.values >= 0.4)*1))
#       5 print("* Precision = labelled as x / how many were actually x in the ones that were labelled")
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'EstProb'
