# %% [markdown]
# <h1 align="center" style="background-color:#616161;color:white">Create Time Period Dataset</h1>

# %% [markdown]
# <div style="background-color:white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Input Parameters</div>

# %%
# Root path
#root = "C:/DS/Github/MusicRecommendation"  # BA, Windows
root = "/home/badrul/git/EventPrediction"  # BA, Linux
#root = "/home/ubuntu/EventPrediction"  # BA, Aws

# %% [markdown]
# <div style="background-color:white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Import Libraries</div>

# %% [markdown]
# <code>Standard code used in every page. Not all of these libraries are used here.</code>

# %%
# Core
import numpy as np
import pandas as pd
from IPython.core.debugger import Tracer    # Used for debugging
import logging

# File and database management
import csv
import os
import sys
import json
import sqlite3
from pathlib import Path

# Date/Time
import datetime
#import time
#from pendulum import Pendulum

# Visualization
#from ggplot import *                        # Preferred vis tool
import matplotlib.pyplot as plt             # Quick viz tool
# %matplotlib inline

# Data science (comment out if not needed)
#from sklearn.manifold import TSNE
from sklearn.metrics import roc_curve, auc

# Misc
import random

#-------------- Custom Libs -----------------#
os.chdir(root)

# Import the codebase module
fPath = root + "/1_codemodule"
if fPath not in sys.path: sys.path.append(fPath)

# Custom Libs
import coreCode as cc
import lastfmCode as fm

# %% [markdown]
# <div style="background-color:#white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Declare Functions</div>

# %%
# Function definition

### Not in use ###
#def toTimeSlot(dt, PeriodGranularity):
#    # If you change this, be sure to changne it further down too
#    return str(int(dt.strftime('%w'))+1) +dt.strftime('-%H-') + str(int((int(dt.strftime('%M'))/PeriodGranularity+1)))

# %% [markdown]
# <div style="background-color:#white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Load settings</div>

# %%
settingsDict =  cc.loadSettings()
dbPath = root + settingsDict['mainDbPath_hlf']
fmSimilarDbPath = root + settingsDict['fmSimilarDbPath']
fmTagsDbPath = root + settingsDict['fmTagsDbPath']
trackMetaDbPath = root + settingsDict['trackmetadata']
periodGranularity = int(settingsDict['periodGranularity'])

# %% [markdown]
# <h3 style="background-color:#616161;color:white">1. Convert data into a more usable form</h3>
#
# Here were "fill in the blanks" - for every period where the user did not listen to data a row of data is inserted.
#
# As part of start and end dates for every period, at the granularity level specified above, is setup.

# %% [markdown]
# <div style="background-color:#white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Populate tblPeriod</div>

# %%
con = sqlite3.connect(dbPath)
cur = con.cursor()

SQLStr = "Select PlayedTimestamp from tblMain"
tblMain = pd.read_sql_query(SQLStr, con)
tblMain.PlayedTimestamp = pd.to_datetime(tblMain.PlayedTimestamp)

startDT = tblMain.PlayedTimestamp.min()
endDT = tblMain.PlayedTimestamp.max()

# This is the main line. Makes a call to code stored in the core module.
dtArray = cc.createDateTimeRange(startDT,endDT, periodGranularity)

# Save to db and create the 'HrsFrom6pm' field too
cur.execute('Delete from tblPeriod')
for idx, dt in enumerate(dtArray):
    HrsFrom5pm = abs(int(dt.strftime('%H')) - 17)
    SqlStr="INSERT INTO tblPeriod (PeriodID, PeriodDateTime, HrsFrom5pm) VALUES ({},'{}',{})".format(idx, dt,HrsFrom5pm)
    cur.execute(SqlStr)

con.commit()
con.close()
print('Ok')
# Out:
# Ok

# %% [markdown]
# <div style="background-color:#white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Read in  tblPeriod, tblMain, and tblUser.</div>

# %%
con = sqlite3.connect(dbPath)
cur = con.cursor()

### Read tblPeriod, tblMain, and tblUser. These will be re-used later too.

# tblPeriod
SQLStr = "Select * from tblPeriod"
tblPeriod = pd.read_sql_query(SQLStr, con)
tblPeriod.PeriodDateTime = pd.to_datetime(tblPeriod.PeriodDateTime)

# tblUser
SQLStr = "Select UserID as UserID, FirstPlay, LastPlay, TestUser from tblUsers"
tblUser = pd.read_sql_query(SQLStr, con)
tblUser.FirstPlay = pd.to_datetime(tblUser.FirstPlay)
tblUser.LastPlay = pd.to_datetime(tblUser.LastPlay)
# Bring in the PeriodID into tblUsers for the First and Last play
idx = tblPeriod.PeriodDateTime.searchsorted(tblUser['FirstPlay'].values)
tblUser['FirstPlayPeriodID'] = idx
idx = tblPeriod.PeriodDateTime.searchsorted(tblUser['LastPlay'].values)
tblUser['LastPlayPeriodID'] = idx

# tblMain
SQLStr = "Select UserID, PlayedTimestamp from tblMain"
tblMain = pd.read_sql_query(SQLStr, con)
tblMain.PlayedTimestamp = pd.to_datetime(tblMain.PlayedTimestamp)
# Bring in the PeriodID into tblMain
idx = tblPeriod.PeriodDateTime.searchsorted(tblMain['PlayedTimestamp'].values)
tblMain['PeriodID'] = idx

# Drop the timetamp col and just use periodID
tblMain=tblMain.groupby(['UserID','PeriodID']).count().reset_index()

con.close()
print('Ok')
# Out:
# Ok

# %% [markdown]
# <div style="background-color:#white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Create a table that has both the original 'plays' + 'non-plays', utilizing the periods defined previously</div>

# %%
con = sqlite3.connect(dbPath)
cur = con.cursor()

SqlStr = "Delete from tblMain2"
cur.execute(SqlStr)
con.commit()
i=1
for row in tblUser.itertuples():
    print("Processing user {} out of {}".format(i,len(tblUser)))
    i+=1
    m = tblMain[tblMain.UserID == row.UserID]
    for pid in range (row.FirstPlayPeriodID,row.LastPlayPeriodID):
        # Check if the user listened to music in this period
        playedMusic = m[m.PeriodID == pid]
        playedMusic = (len(playedMusic) > 0) *1
        SqlStr="Insert into tblMain2 (UserID, PeriodID, PlayedMusic) Values ({},{},{})".format(row.UserID, pid,playedMusic)
        cur.execute(SqlStr)    


## Use this if you wish to test for just one user instead
#row = tblUser.iloc[0]
#m = tblMain[tblMain.UserID == row.UserID]
#for pid in range (row.FirstPlayPeriodID,row.LastPlayPeriodID):
    # Check if the user listened to music in this period
#    playedMusic = m[m.PeriodID == pid]
#    playedMusic = (len(playedMusic) > 0) *1
#    SqlStr="Insert into tblMain2 (UserID, PeriodID, PlayedMusic) Values ({},{},{})".format(row.UserID, pid,playedMusic)
#    cur.execute(SqlStr)    

con.commit()
con.close()
print('Ok')
# Out:
# Processing user 1 out of 381
# Processing user 2 out of 381
# Processing user 3 out of 381
# Processing user 4 out of 381
# Processing user 5 out of 381
# Processing user 6 out of 381
# Processing user 7 out of 381
# Processing user 8 out of 381
# Processing user 9 out of 381
# Processing user 10 out of 381
# Processing user 11 out of 381
# Processing user 12 out of 381
# Processing user 13 out of 381
# Processing user 14 out of 381
# Processing user 15 out of 381
# Processing user 16 out of 381
# Processing user 17 out of 381
# Processing user 18 out of 381
# Processing user 19 out of 381
# Processing user 20 out of 381
# Processing user 21 out of 381
# Processing user 22 out of 381
# Processing user 23 out of 381
# Processing user 24 out of 381
# Processing user 25 out of 381
# Processing user 26 out of 381
# Processing user 27 out of 381
# Processing user 28 out of 381
# Processing user 29 out of 381
# Processing user 30 out of 381
# Processing user 31 out of 381
# Processing user 32 out of 381
# Processing user 33 out of 381
# Processing user 34 out of 381
# Processing user 35 out of 381
# Processing user 36 out of 381
# Processing user 37 out of 381
# Processing user 38 out of 381
# Processing user 39 out of 381
# Processing user 40 out of 381
# Processing user 41 out of 381
# Processing user 42 out of 381
# Processing user 43 out of 381
# Processing user 44 out of 381
# Processing user 45 out of 381
# Processing user 46 out of 381
# Processing user 47 out of 381
# Processing user 48 out of 381
# Processing user 49 out of 381
# Processing user 50 out of 381
# Processing user 51 out of 381
# Processing user 52 out of 381
# Processing user 53 out of 381
# Processing user 54 out of 381
# Processing user 55 out of 381
# Processing user 56 out of 381
# Processing user 57 out of 381
# Processing user 58 out of 381
# Processing user 59 out of 381
# Processing user 60 out of 381
# Processing user 61 out of 381
# Processing user 62 out of 381
# Processing user 63 out of 381
# Processing user 64 out of 381
# Processing user 65 out of 381
# Processing user 66 out of 381
# Processing user 67 out of 381
# Processing user 68 out of 381
# Processing user 69 out of 381
# Processing user 70 out of 381
# Processing user 71 out of 381
# Processing user 72 out of 381
# Processing user 73 out of 381
# Processing user 74 out of 381
# Processing user 75 out of 381
# Processing user 76 out of 381
# Processing user 77 out of 381
# Processing user 78 out of 381
# Processing user 79 out of 381
# Processing user 80 out of 381
# Processing user 81 out of 381
# Processing user 82 out of 381
# Processing user 83 out of 381
# Processing user 84 out of 381
# Processing user 85 out of 381
# Processing user 86 out of 381
# Processing user 87 out of 381
# Processing user 88 out of 381
# Processing user 89 out of 381
# Processing user 90 out of 381
# Processing user 91 out of 381
# Processing user 92 out of 381
# Processing user 93 out of 381
# Processing user 94 out of 381
# Processing user 95 out of 381
# Processing user 96 out of 381
# Processing user 97 out of 381
# Processing user 98 out of 381
# Processing user 99 out of 381
# Processing user 100 out of 381
# Processing user 101 out of 381
# Processing user 102 out of 381
# Processing user 103 out of 381
# Processing user 104 out of 381
# Processing user 105 out of 381
# Processing user 106 out of 381
# Processing user 107 out of 381
# Processing user 108 out of 381
# Processing user 109 out of 381
# Processing user 110 out of 381
# Processing user 111 out of 381
# Processing user 112 out of 381
# Processing user 113 out of 381
# Processing user 114 out of 381
# Processing user 115 out of 381
# Processing user 116 out of 381
# Processing user 117 out of 381
# Processing user 118 out of 381
# Processing user 119 out of 381
# Processing user 120 out of 381
# Processing user 121 out of 381
# Processing user 122 out of 381
# Processing user 123 out of 381
# Processing user 124 out of 381
# Processing user 125 out of 381
# Processing user 126 out of 381
# Processing user 127 out of 381
# Processing user 128 out of 381
# Processing user 129 out of 381
# Processing user 130 out of 381
# Processing user 131 out of 381
# Processing user 132 out of 381
# Processing user 133 out of 381
# Processing user 134 out of 381
# Processing user 135 out of 381
# Processing user 136 out of 381
# Processing user 137 out of 381
# Processing user 138 out of 381
# Processing user 139 out of 381
# Processing user 140 out of 381
# Processing user 141 out of 381
# Processing user 142 out of 381
# Processing user 143 out of 381
# Processing user 144 out of 381
# Processing user 145 out of 381
# Processing user 146 out of 381
# Processing user 147 out of 381
# Processing user 148 out of 381
# Processing user 149 out of 381
# Processing user 150 out of 381
# Processing user 151 out of 381
# Processing user 152 out of 381
# Processing user 153 out of 381
# Processing user 154 out of 381
# Processing user 155 out of 381
# Processing user 156 out of 381
# Processing user 157 out of 381
# Processing user 158 out of 381
# Processing user 159 out of 381
# Processing user 160 out of 381
# Processing user 161 out of 381
# Processing user 162 out of 381
# Processing user 163 out of 381
# Processing user 164 out of 381
# Processing user 165 out of 381
# Processing user 166 out of 381
# Processing user 167 out of 381
# Processing user 168 out of 381
# Processing user 169 out of 381
# Processing user 170 out of 381
# Processing user 171 out of 381
# Processing user 172 out of 381
# Processing user 173 out of 381
# Processing user 174 out of 381
# Processing user 175 out of 381
# Processing user 176 out of 381
# Processing user 177 out of 381
# Processing user 178 out of 381
# Processing user 179 out of 381
# Processing user 180 out of 381
# Processing user 181 out of 381
# Processing user 182 out of 381
# Processing user 183 out of 381
# Processing user 184 out of 381
# Processing user 185 out of 381
# Processing user 186 out of 381
# Processing user 187 out of 381
# Processing user 188 out of 381
# Processing user 189 out of 381
# Processing user 190 out of 381
# Processing user 191 out of 381
# Processing user 192 out of 381
# Processing user 193 out of 381
# Processing user 194 out of 381
# Processing user 195 out of 381
# Processing user 196 out of 381
# Processing user 197 out of 381
# Processing user 198 out of 381
# Processing user 199 out of 381
# Processing user 200 out of 381
# Processing user 201 out of 381
# Processing user 202 out of 381
# Processing user 203 out of 381
# Processing user 204 out of 381
# Processing user 205 out of 381
# Processing user 206 out of 381
# Processing user 207 out of 381
# Processing user 208 out of 381
# Processing user 209 out of 381
# Processing user 210 out of 381
# Processing user 211 out of 381
# Processing user 212 out of 381
# Processing user 213 out of 381
# Processing user 214 out of 381
# Processing user 215 out of 381
# Processing user 216 out of 381
# Processing user 217 out of 381
# Processing user 218 out of 381
# Processing user 219 out of 381
# Processing user 220 out of 381
# Processing user 221 out of 381
# Processing user 222 out of 381
# Processing user 223 out of 381
# Processing user 224 out of 381
# Processing user 225 out of 381
# Processing user 226 out of 381
# Processing user 227 out of 381
# Processing user 228 out of 381
# Processing user 229 out of 381
# Processing user 230 out of 381
# Processing user 231 out of 381
# Processing user 232 out of 381
# Processing user 233 out of 381
# Processing user 234 out of 381
# Processing user 235 out of 381
# Processing user 236 out of 381
# Processing user 237 out of 381
# Processing user 238 out of 381
# Processing user 239 out of 381
# Processing user 240 out of 381
# Processing user 241 out of 381
# Processing user 242 out of 381
# Processing user 243 out of 381
# Processing user 244 out of 381
# Processing user 245 out of 381
# Processing user 246 out of 381
# Processing user 247 out of 381
# Processing user 248 out of 381
# Processing user 249 out of 381
# Processing user 250 out of 381
# Processing user 251 out of 381
# Processing user 252 out of 381
# Processing user 253 out of 381
# Processing user 254 out of 381
# Processing user 255 out of 381
# Processing user 256 out of 381
# Processing user 257 out of 381
# Processing user 258 out of 381
# Processing user 259 out of 381
# Processing user 260 out of 381
# Processing user 261 out of 381
# Processing user 262 out of 381
# Processing user 263 out of 381
# Processing user 264 out of 381
# Processing user 265 out of 381
# Processing user 266 out of 381
# Processing user 267 out of 381
# Processing user 268 out of 381
# Processing user 269 out of 381
# Processing user 270 out of 381
# Processing user 271 out of 381
# Processing user 272 out of 381
# Processing user 273 out of 381
# Processing user 274 out of 381
# Processing user 275 out of 381
# Processing user 276 out of 381
# Processing user 277 out of 381
# Processing user 278 out of 381
# Processing user 279 out of 381
# Processing user 280 out of 381
# Processing user 281 out of 381
# Processing user 282 out of 381
# Processing user 283 out of 381
# Processing user 284 out of 381
# Processing user 285 out of 381
# Processing user 286 out of 381
# Processing user 287 out of 381
# Processing user 288 out of 381
# Processing user 289 out of 381
# Processing user 290 out of 381
# Processing user 291 out of 381
# Processing user 292 out of 381
# Processing user 293 out of 381
# Processing user 294 out of 381
# Processing user 295 out of 381
# Processing user 296 out of 381
# Processing user 297 out of 381
# Processing user 298 out of 381
# Processing user 299 out of 381
# Processing user 300 out of 381
# Processing user 301 out of 381
# Processing user 302 out of 381
# Processing user 303 out of 381
# Processing user 304 out of 381
# Processing user 305 out of 381
# Processing user 306 out of 381
# Processing user 307 out of 381
# Processing user 308 out of 381
# Processing user 309 out of 381
# Processing user 310 out of 381
# Processing user 311 out of 381
# Processing user 312 out of 381
# Processing user 313 out of 381
# Processing user 314 out of 381
# Processing user 315 out of 381
# Processing user 316 out of 381
# Processing user 317 out of 381
# Processing user 318 out of 381
# Processing user 319 out of 381
# Processing user 320 out of 381
# Processing user 321 out of 381
# Processing user 322 out of 381
# Processing user 323 out of 381
# Processing user 324 out of 381
# Processing user 325 out of 381
# Processing user 326 out of 381
# Processing user 327 out of 381
# Processing user 328 out of 381
# Processing user 329 out of 381
# Processing user 330 out of 381
# Processing user 331 out of 381
# Processing user 332 out of 381
# Processing user 333 out of 381
# Processing user 334 out of 381
# Processing user 335 out of 381
# Processing user 336 out of 381
# Processing user 337 out of 381
# Processing user 338 out of 381
# Processing user 339 out of 381
# Processing user 340 out of 381
# Processing user 341 out of 381
# Processing user 342 out of 381
# Processing user 343 out of 381
# Processing user 344 out of 381
# Processing user 345 out of 381
# Processing user 346 out of 381
# Processing user 347 out of 381
# Processing user 348 out of 381
# Processing user 349 out of 381
# Processing user 350 out of 381
# Processing user 351 out of 381
# Processing user 352 out of 381
# Processing user 353 out of 381
# Processing user 354 out of 381
# Processing user 355 out of 381
# Processing user 356 out of 381
# Processing user 357 out of 381
# Processing user 358 out of 381
# Processing user 359 out of 381
# Processing user 360 out of 381
# Processing user 361 out of 381
# Processing user 362 out of 381
# Processing user 363 out of 381
# Processing user 364 out of 381
# Processing user 365 out of 381
# Processing user 366 out of 381
# Processing user 367 out of 381
# Processing user 368 out of 381
# Processing user 369 out of 381
# Processing user 370 out of 381
# Processing user 371 out of 381
# Processing user 372 out of 381
# Processing user 373 out of 381
# Processing user 374 out of 381
# Processing user 375 out of 381
# Processing user 376 out of 381
# Processing user 377 out of 381
# Processing user 378 out of 381
# Processing user 379 out of 381
# Processing user 380 out of 381
# Processing user 381 out of 381
# Ok

# %% [markdown]
# <div style="background-color:#white; color:#008000; font-family: 'Courier New, Monospace;font-weight: bold">Manual/offline checks have to be done but here we do a quick plot</div>

# %%
# Some quick checks
con = sqlite3.connect(dbPath)
SQLStr = "Select * from tblMain2"
tblMain2 = pd.read_sql_query(SQLStr, con)
con.close()

tblMain2.head(20)
# Out:
#     UserID  PeriodID  PlayedMusic
# 0        1     26188            1
# 1        1     26189            1
# 2        1     26190            1
# 3        1     26191            1
# 4        1     26192            1
# 5        1     26193            1
# 6        1     26194            1
# 7        1     26195            1
# 8        1     26196            1
# 9        1     26197            1
# 10       1     26198            0
# 11       1     26199            0
# 12       1     26200            0
# 13       1     26201            0
# 14       1     26202            0
# 15       1     26203            0
# 16       1     26204            0
# 17       1     26205            0
# 18       1     26206            0
# 19       1     26207            0

# %%
a=tblMain2[0:336].plot.scatter('PeriodID', 'PlayedMusic')
a.set_title('1 week period')

# %% [markdown]
# <h3 style="background-color:#616161;color:white">2. Create monthly time-series data</h3>

# %%
# Good for report: Select strftime('%H',PlayedTimestamp) as H, count(*) as C from tblMain group by H order by C

con = sqlite3.connect(dbPath)
c = con.cursor()

# Create tblTimeSeriesData


### Only run this if not continuing:
#####################c.execute('DROP TABLE IF EXISTS tblTimeSeriesData')
#####################sqlStr = "CREATE TABLE 'tblTimeSeriesData' ('PeriodID' Integer, 'UserID' Integer, 'HrsFrom5pm' Integer, 'isSun' Integer, 'isMon' Integer, 'isTue' Integer, 'isWed' Integer, 'isThu' Integer, 'isFri' Integer, 'isSat' Integer, 't' integer, 't1' Integer, 't2' Integer,'t3' Integer,'t4' Integer,'t5' Integer,'t10' Integer,'t12hrs' Integer,'t23_5hrs' Integer,'t24hrs' Integer,'t24_5hrs' Integer,'t1wk' Integer,'t2wks' Integer,'t3wks' Integer,'t4wks' Integer)"
#####################c.execute(sqlStr)

# Go through each user
for row in tblUser.itertuples():
    print('Processing user {} of {}'.format(row.UserID, tblUser.shape[0]))
    userID = row.UserID
    # Bring back the data for that user
    SQLStr = "Select count(*) from tblTimeSeriesData where UserID = {}".format(userID)
    
    if pd.read_sql_query(SQLStr, con).values == 0:
        SQLStr = "Select * from tblMain2 where UserID = {} order by PeriodID".format(userID)
        tblMain2 = pd.read_sql_query(SQLStr, con)
        tblMain2.sort_values('PeriodID')
        tblMain2.set_index('PeriodID',inplace = True)

        minPeriodID = tblMain2.index.min()
        maxPeriodID = tblMain2.index.max()
        periodsInMonth = int(60/periodGranularity)*24*7*4

        # Go through all the periods for this user and turn into time-series data
        for i in range(minPeriodID+periodsInMonth,maxPeriodID):

            periodDt = tblPeriod[tblPeriod.PeriodID == i].PeriodDateTime
            HrsFrom5pm = int(tblPeriod[tblPeriod.PeriodID == i].HrsFrom5pm)
            dayOfWk = int(periodDt.dt.strftime('%w'))
            isSun = (dayOfWk ==0)*1
            isMon = (dayOfWk ==1)*1
            isTue = (dayOfWk ==2)*1
            isWed = (dayOfWk ==3)*1
            isThu = (dayOfWk ==4)*1
            isFri = (dayOfWk ==5)*1
            isSat = (dayOfWk ==6)*1

            t =int(tblMain2.loc[i].PlayedMusic)
            t1 = int(tblMain2.loc[i-1].PlayedMusic)
            t2 = int(tblMain2.loc[i-2].PlayedMusic)
            t3 = int(tblMain2.loc[i-3].PlayedMusic)
            t4 = int(tblMain2.loc[ i-4].PlayedMusic)
            t5 = int(tblMain2.loc[i-5].PlayedMusic)

            t12hrs = int(tblMain2.loc[i-int(60/periodGranularity)*12].PlayedMusic)   
            t23_5hrs = int(tblMain2.loc[i-int(60/periodGranularity)*23.5].PlayedMusic)
            t24hrs = int(tblMain2.loc[i-int(60/periodGranularity)*24].PlayedMusic)
            t24_5hrs = int(tblMain2.loc[i-int(60/periodGranularity)*24.5].PlayedMusic)
            t1wk = int(tblMain2.loc[i-int(60/periodGranularity)*168].PlayedMusic)
            t2wks = int(tblMain2.loc[i-int(60/periodGranularity)*336].PlayedMusic)
            t3wks = int(tblMain2.loc[i-int(60/periodGranularity)*504].PlayedMusic)
            t4wks = int(tblMain2.loc[i-int(60/periodGranularity)*672].PlayedMusic)

            SqlStr = "Insert into tblTimeSeriesData (PeriodID, UserID, HrsFrom5pm, isSun,isMon,isTue,isWed,isThu,isFri,isSat,t,t1,t2,t3,t4,t5,t12hrs,t23_5hrs, t24hrs, t24_5hrs, t1wk,t2wks,t3wks,t4wks) Values ({},{},{},{},{},{},{},{},{},{},{},{},{},{},{},{},{},{},{},{},{},{},{},{})".format(i,userID,HrsFrom5pm,isSun,isMon,isTue,isWed,isThu,isFri,isSat,t,t1,t2,t3,t4,t5,t12hrs,t23_5hrs,t24hrs,t24_5hrs,t1wk,t2wks,t3wks,t4wks)
            c.execute(SqlStr)
        con.commit()


con.close()
print('Ok')
# Out:
# Processing user 1 of 381
# Processing user 2 of 381
# Processing user 3 of 381
# Processing user 4 of 381
# Processing user 5 of 381
# Processing user 6 of 381
# Processing user 7 of 381
# Processing user 8 of 381
# Processing user 9 of 381
# Processing user 10 of 381
# Processing user 11 of 381
# Processing user 12 of 381
# Processing user 13 of 381
# Processing user 14 of 381
# Processing user 15 of 381
# Processing user 16 of 381
# Processing user 17 of 381
# Processing user 18 of 381
# Processing user 19 of 381
# Processing user 20 of 381
# Processing user 21 of 381
# Processing user 22 of 381
# Processing user 23 of 381
# Processing user 24 of 381
# Processing user 25 of 381
# Processing user 26 of 381
# Processing user 27 of 381
# Processing user 28 of 381
# Processing user 29 of 381
# Processing user 30 of 381
# Processing user 31 of 381
# Processing user 32 of 381
# Processing user 33 of 381
# Processing user 34 of 381
# Processing user 35 of 381
# Processing user 36 of 381
# Processing user 37 of 381
# Processing user 38 of 381
# Processing user 39 of 381
# Processing user 40 of 381
# Processing user 41 of 381
# Processing user 42 of 381
# Processing user 43 of 381
# Processing user 44 of 381
# Processing user 45 of 381
# Processing user 46 of 381
# Processing user 47 of 381
# Processing user 48 of 381
# Processing user 49 of 381
# Processing user 50 of 381
# Processing user 51 of 381
# Processing user 52 of 381
# Processing user 53 of 381
# Processing user 54 of 381
# Processing user 55 of 381
# Processing user 56 of 381
# Processing user 57 of 381
# Processing user 58 of 381
# Processing user 59 of 381
# Processing user 60 of 381
# Processing user 61 of 381
# Processing user 62 of 381
# Processing user 63 of 381
# Processing user 64 of 381
# Processing user 65 of 381
# Processing user 66 of 381
# Processing user 67 of 381
# Processing user 68 of 381
# Processing user 69 of 381
# Processing user 70 of 381
# Processing user 71 of 381
# Processing user 72 of 381
# Processing user 73 of 381
# Processing user 74 of 381
# Processing user 75 of 381
# Processing user 76 of 381
# Processing user 77 of 381
# Processing user 78 of 381
# Processing user 79 of 381
# Processing user 80 of 381
# Processing user 81 of 381
# Processing user 82 of 381
# Processing user 83 of 381
# Processing user 84 of 381
# Processing user 85 of 381
# Processing user 86 of 381
# Processing user 87 of 381
# Processing user 88 of 381
# Processing user 89 of 381
# Processing user 90 of 381
# Processing user 91 of 381
# Processing user 92 of 381
# Processing user 93 of 381
# Processing user 94 of 381
# Processing user 95 of 381
# Processing user 96 of 381
# Processing user 97 of 381
# Processing user 98 of 381
# Processing user 99 of 381
# Processing user 100 of 381
# Processing user 101 of 381
# Processing user 102 of 381
# Processing user 103 of 381
# Processing user 104 of 381
# Processing user 105 of 381
# Processing user 106 of 381
# Processing user 107 of 381
# Processing user 108 of 381
# Processing user 109 of 381
# Processing user 110 of 381
# Processing user 111 of 381
# Processing user 112 of 381
# Processing user 113 of 381
# Processing user 114 of 381
# Processing user 115 of 381
# Processing user 116 of 381
# Processing user 117 of 381
# Processing user 118 of 381
# Processing user 119 of 381
# Processing user 120 of 381
# Processing user 121 of 381
# Processing user 122 of 381
# Processing user 123 of 381
# Processing user 124 of 381
# Processing user 125 of 381
# Processing user 126 of 381
# Processing user 127 of 381
# Processing user 128 of 381
# Processing user 129 of 381
# Processing user 130 of 381
# Processing user 131 of 381
# Processing user 132 of 381
# Processing user 133 of 381
# Processing user 134 of 381
# Processing user 135 of 381
# Processing user 136 of 381
# Processing user 137 of 381
# Processing user 138 of 381
# Processing user 139 of 381
# Processing user 140 of 381
# Processing user 141 of 381
# Processing user 142 of 381
# Processing user 143 of 381
# Processing user 144 of 381
# Processing user 145 of 381
# Processing user 146 of 381
# Processing user 147 of 381
# Processing user 148 of 381
# Processing user 149 of 381
# Processing user 150 of 381
# Processing user 151 of 381
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-9aab5858ec2b> in <module>()
#      43             isSat = (dayOfWk ==6)*1
#      44
# ---> 45             t =int(tblMain2.loc[i].PlayedMusic)
#      46             t1 = int(tblMain2.loc[i-1].PlayedMusic)
#      47             t2 = int(tblMain2.loc[i-2].PlayedMusic)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1550         # fall thru to straight lookup
#    1551         self._has_valid_type(key, axis)
# -> 1552         return self._get_label(key, axis=axis)
#    1553
#    1554
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     134             raise IndexingError('no slices here, handle elsewhere')
#     135
# --> 136         return self.obj._xs(label, axis=axis)
#     137
#     138     def _get_loc(self, key, axis=0):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    2055             result = self._constructor_sliced(
#    2056                 new_values, index=self.columns,
# -> 2057                 name=self.index[loc], dtype=new_values.dtype)
#    2058
#    2059         else:
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     246             else:
#     247                 data = _sanitize_array(data, index, dtype, copy,
# --> 248                                        raise_cast_failure=True)
#     249
#     250                 data = SingleBlockManager(data, index, fastpath=True)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    2996
#    2997     # scalar like, GH
# -> 2998     if getattr(subarr, 'ndim', 0) == 0:
#    2999         if isinstance(data, list):  # pragma: no cover
#    3000             subarr = np.array(data, dtype=object)
#
# KeyboardInterrupt:

# %%
con.close()

# %%
con.commit()
c=con.cursor()
c.execute("Delete from tblTimeSeriesData where (t=1 and t1+t2+t3+t4+t5+t12hrs+t23_5hrs+t24hrs+t24_5hrs+t1wk+t2wks+t3wks+t4wks = 0)")
con.close()
print('Ok')
